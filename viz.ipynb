# %% [markdown]
# # todo

# %%
import pickle
import ribs

file_name = "random_results_2024-10-19_15-00-11"
# file_name = "results"

with open(f"data/{file_name}.pkl", "rb") as f:
    results = pickle.load(f)

# %%
#random 16 iter
from ribs.visualize import grid_archive_heatmap
grid_archive_heatmap(results["archive"], vmax=10, vmin=0)

# %%
# CMA-ME 16 itr 
from ribs.visualize import grid_archive_heatmap
grid_archive_heatmap(results["archive"], vmax=10, vmin=0)
